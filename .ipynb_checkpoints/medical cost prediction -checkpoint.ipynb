# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df=pd.read_csv("Hospital_Cost_Report.csv")

# %%
df.head()
# Out:
#    rpt_rec_num  Provider CCN                  Hospital Name  \
# 0       623132         10032               WEDOWEE HOSPITAL
# 1       628158        250042    NORTHWEST MS MEDICAL CENTER
# 2       628833        440235  BIG SOUTH FORK MEDICAL CENTER
# 3       631016         50523    SUTTER DELTA MEDICAL CENTER
# 4       631094         50305      ALTA BATES MEDICAL CENTER
#
#           Street Address        City State Code Zip Code        County  \
# 0  301 NORTH MAIN STREET     WEDOWEE         AL    36278      RANDOLPH
# 1    1970 HOSPITAL DRIVE  CLARKSDALE         MS    38614       COAHOMA
# 2       18797 ALBERTA ST      ONEIDA         TN    37841         SCOTT
# 3     3901 LONE TREE WAY     ANTIOCH         CA   94509-  CONTRA COSTA
# 4      2450 ASHBY AVENUE    BERKELEY         CA   94705-       ALAMEDA
#
#    Medicare CBSA Number Rural Versus Urban CCN Facility Type  Provider Type  \
# 0               99901.0                  R               STH              1
# ...

# %%
df.shape
# Out:
# (6156, 128)

# %%
df.columns
# Out:
# Index(['rpt_rec_num', 'Provider CCN', 'Hospital Name', 'Street Address',
#        'City', 'State Code', 'Zip Code', 'County', 'Medicare CBSA Number',
#        'Rural Versus Urban',
#        ...
#        'Net Income from Service to Patients', 'Total Other Income',
#        'Total Income', 'Total Other Expenses', 'Net Income',
#        'Cost To Charge Ratio', 'Net Revenue from Medicaid', 'Medicaid Charges',
#        'Net Revenue from Stand-Alone SCHIP', 'Stand-Alone SCHIP Charges'],
#       dtype='object', length=128)

# %%
df.isna().sum()
# Out:
# 4

# %%
df['rpt_rec_num'].isna().sum() > 0
# Out:
# False

# %%
for i in df.columns:
    if df[i].isna().sum() > 0:
        print(i)
        df_null = i
df_null
# Out:
# Street Address
# County
# Medicare CBSA Number
# Rural Versus Urban
# FTE - Employees on Payroll
# Number of Interns and Residents (FTE)
# Total Days Title V
# Total Days Title XVIII
# Total Days Title XIX
# Total Days (V + XVIII + XIX + Unknown)
# Number of Beds
# Total Bed Days Available
# Total Discharges Title V
# Total Discharges Title XVIII
# Total Discharges Title XIX
# Total Discharges (V + XVIII + XIX + Unknown)
# Total Days Title V + Total for all Subproviders
# Total Days Title XVIII + Total for all Subproviders
# Total Days Title XIX + Total for all Subproviders
# Total Days (V + XVIII + XIX + Unknown) + Total for all Subproviders
# Number of Beds + Total for all Subproviders
# Total Bed Days Available + Total for all Subproviders
# Total Discharges Title V + Total for all Subproviders
# Total Discharges Title XVIII + Total for all Subproviders
# Total Discharges Title XIX + Total for all Subproviders
# ...

# %%
df[df.columns[df.isna().any()]].isna().sum()
# Out:
# Street Address                                                                  4
# County                                                                        451
# Medicare CBSA Number                                                           77
# Rural Versus Urban                                                             77
# FTE - Employees on Payroll                                                    110
# Number of Interns and Residents (FTE)                                        4788
# Total Days Title V                                                           5931
# Total Days Title XVIII                                                        132
# Total Days Title XIX                                                          995
# Total Days (V + XVIII + XIX + Unknown)                                         90
# Number of Beds                                                                 83
# ...

# %% [markdown]
# 1. feature selection
# 2. delete feature where null is more then 5000
# 3. set diffrent data set using dtype and change the columns name
# 4. null handling
# 5. concat
# 6. corr
# 7. distribution
